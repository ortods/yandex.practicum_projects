# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Изучум-датасеты" data-toc-modified-id="Изучум-датасеты-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Изучум датасеты</a></span><ul class="toc-item"><li><span><a href="#Изучим-обучающий-датасет." data-toc-modified-id="Изучим-обучающий-датасет.-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Изучим обучающий датасет.</a></span></li><li><span><a href="#Изучим-тестовый-датасет" data-toc-modified-id="Изучим-тестовый-датасет-1.1.2"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>Изучим тестовый датасет</a></span></li><li><span><a href="#Изучим-полный-датасет" data-toc-modified-id="Изучим-полный-датасет-1.1.3"><span class="toc-item-num">1.1.3&nbsp;&nbsp;</span>Изучим полный датасет</a></span></li></ul></li><li><span><a href="#Проверим-формулу-вычисления-эффективности-обогащения" data-toc-modified-id="Проверим-формулу-вычисления-эффективности-обогащения-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Проверим формулу вычисления эффективности обогащения</a></span></li><li><span><a href="#Проанализируем-признаки,-недоступные-в-тестовой-выборке." data-toc-modified-id="Проанализируем-признаки,-недоступные-в-тестовой-выборке.-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Проанализируем признаки, недоступные в тестовой выборке.</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Обработка-дубликатов" data-toc-modified-id="Обработка-дубликатов-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>Обработка дубликатов</a></span></li><li><span><a href="#Обработка-пропусков" data-toc-modified-id="Обработка-пропусков-1.4.2"><span class="toc-item-num">1.4.2&nbsp;&nbsp;</span>Обработка пропусков</a></span></li></ul></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Как-меняется-концентрация-металлов-(Au,-Ag,-Pb)-на-различных-этапах-очистки." data-toc-modified-id="Как-меняется-концентрация-металлов-(Au,-Ag,-Pb)-на-различных-этапах-очистки.-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Как меняется концентрация металлов (Au, Ag, Pb) на различных этапах очистки.</a></span></li><li><span><a href="#Сравние-распределения-размеров-гранул-сырья-на-обучающей-и-тестовой-выборках." data-toc-modified-id="Сравние-распределения-размеров-гранул-сырья-на-обучающей-и-тестовой-выборках.-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Сравние распределения размеров гранул сырья на обучающей и тестовой выборках.</a></span></li><li><span><a href="#Исследуйте-суммарную-концентрацию-всех-веществ-на-разных-стадиях:-в-сырье,-в-черновом-и-финальном-концентратах." data-toc-modified-id="Исследуйте-суммарную-концентрацию-всех-веществ-на-разных-стадиях:-в-сырье,-в-черновом-и-финальном-концентратах.-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Исследуйте суммарную концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах.</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Модель" data-toc-modified-id="Модель-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Модель</a></span><ul class="toc-item"><li><span><a href="#Функция-для-вычисления-итоговой-sMAPE." data-toc-modified-id="Функция-для-вычисления-итоговой-sMAPE.-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Функция для вычисления итоговой sMAPE.</a></span></li><li><span><a href="#Определяем-признаки-и-целевые-признаки." data-toc-modified-id="Определяем-признаки-и-целевые-признаки.-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Определяем признаки и целевые признаки.</a></span></li><li><span><a href="#Линейная-регрессия" data-toc-modified-id="Линейная-регрессия-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Линейная регрессия</a></span></li><li><span><a href="#Дерево-решений" data-toc-modified-id="Дерево-решений-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Дерево решений</a></span></li><li><span><a href="#Тестируем-модели" data-toc-modified-id="Тестируем-модели-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Тестируем модели</a></span></li></ul></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Выводы</a></span></li></ul></div>

# %% [markdown]
# # Восстановление золота из руды

# %% [markdown]
# Подготовьте прототип модели машинного обучения для «Цифры». Компания разрабатывает решения для эффективной работы промышленных предприятий.
#
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды. Используйте данные с параметрами добычи и очистки.
#
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
#
# Вам нужно:
#
# 1. Подготовить данные;
# 2. Провести исследовательский анализ данных;
# 3. Построить и обучить модель.
#
# Чтобы выполнить проект, обращайтесь к библиотекам *pandas*, *matplotlib* и *sklearn.* Вам поможет их документация.

# %% [markdown]
# **Описание данных**
# - Данные находятся в трёх файлах:
# https://code.s3.yandex.net/datasets/gold_recovery_train_new.csv — обучающая выборка;
# https://code.s3.yandex.net/datasets/gold_recovery_test_new.csv — тестовая выборка;
# https://code.s3.yandex.net/datasets/gold_recovery_full_new.csv — исходные данные.

# %% [markdown]
# Технологический процесс
# - Rougher feed — исходное сырье
# - Rougher additions (или reagent additions) — флотационные реагенты: Xanthate, Sulphate, Depressant
# - Xanthate **— ксантогенат (промотер, или активатор флотации);
# - Sulphate — сульфат (на данном производстве сульфид натрия);
# - Depressant — депрессант (силикат натрия).
# - Rougher process (англ. «грубый процесс») — флотация
# - Rougher tails — отвальные хвосты
# - Float banks — флотационная установка
# - Cleaner process — очистка
# - Rougher Au — черновой концентрат золота
# - Final Au — финальный концентрат золота
#
# ![Image of viruchka_1576238830](https://pictures.s3.yandex.net/resources/viruchka_1576238830.jpg)
#
# Параметры этапов
# - air amount — объём воздуха
# - fluid levels — уровень жидкости
# - feed size — размер гранул сырья
# - feed rate — скорость подачи
#
# Наименование признаков
# Наименование признаков должно быть такое:
# [этап].[тип_параметра].[название_параметра]
# Пример: rougher.input.feed_ag
#
# Возможные значения для блока [этап]:
# - rougher — флотация
# - primary_cleaner — первичная очистка
# - secondary_cleaner — вторичная очистка
# - final — финальные характеристики
#
# Возможные значения для блока [тип_параметра]:
# - input — параметры сырья
# - output — параметры продукта
# - state — параметры, характеризующие текущее состояние этапа
# - calculation — расчётные характеристики

# %% [markdown]
# **Формула расчета эффективности обогащения.**
# ![Image of Recovery_1576238822](https://pictures.s3.yandex.net/resources/Recovery_1576238822.jpg)
#
# где:
# - C — доля золота в концентрате после флотации/очистки;
# - F — доля золота в сырье/концентрате до флотации/очистки;
# - T — доля золота в отвальных хвостах после флотации/очистки.

# %% [markdown]
# **Формула расчета метрики sMAPE (англ. Symmetric Mean Absolute Percentage Error, «симметричное среднее абсолютное процентное отклонение»).**
#
# ![smape_1576238825](https://pictures.s3.yandex.net/resources/smape_1576238825.jpg)
# Обозначения:
# ![y1_1576238832](https://pictures.s3.yandex.net/resources/y1_1576238832.jpg)
# - Значение целевого признака для объекта с порядковым номером i в выборке, на которой измеряется качество.
# ![yi_1_1576238835](https://pictures.s3.yandex.net/resources/yi_1_1576238835.jpg)
# - Значение предсказания для объекта с порядковым номером i, например, в тестовой выборке.
# ![N_1_1576238819](https://pictures.s3.yandex.net/resources/N_1_1576238819.jpg)
#
# <ul><li>Количество объектов в выборке.</li></ul>
#
#
# ![resources/I_1576238817](https://pictures.s3.yandex.net/resources/I_1576238817.jpg)
# - Суммирование по всем объектам выборки (i меняется от 1 до N).

# %% [markdown]
# Требуется спрогнозировать:
# 1. эффективность обогащения чернового концентрата rougher.output.recovery;
# 2. эффективность обогащения финального концентрата final.output.recovery.
#
# **Итоговая метрика:**
#
# ![Image of _smape_1576238814](https://pictures.s3.yandex.net/resources/_smape_1576238814.jpg)

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# Загрузка данных

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_absolute_error
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import make_scorer
from sklearn.model_selection import GridSearchCV
from sklearn.dummy import DummyRegressor
from sklearn.pipeline import Pipeline

# %%
train = pd.read_csv('https://code.s3.yandex.net/datasets/gold_recovery_train_new.csv').set_index('date')
train.index = pd.to_datetime(train.index, format='%Y-%m-%d %H:%M:%S')

test = pd.read_csv('https://code.s3.yandex.net/datasets/gold_recovery_test_new.csv').set_index('date')
test.index = pd.to_datetime(test.index, format='%Y-%m-%d %H:%M:%S')

full = pd.read_csv('https://code.s3.yandex.net/datasets/gold_recovery_full_new.csv').set_index('date')
full.index = pd.to_datetime(full.index, format='%Y-%m-%d %H:%M:%S')

# %% [markdown]
# ### Изучум датасеты

# %% [markdown]
# #### Изучим обучающий датасет.

# %%
train.head()
# Out:
#                      final.output.concentrate_ag  final.output.concentrate_pb  \
# date
# 2016-01-15 00:00:00                     6.055403                     9.889648
# 2016-01-15 01:00:00                     6.029369                     9.968944
# 2016-01-15 02:00:00                     6.055926                    10.213995
# 2016-01-15 03:00:00                     6.047977                     9.977019
# 2016-01-15 04:00:00                     6.148599                    10.142511
#
#                      final.output.concentrate_sol  \
# date
# 2016-01-15 00:00:00                      5.507324
# 2016-01-15 01:00:00                      5.257781
# 2016-01-15 02:00:00                      5.383759
# 2016-01-15 03:00:00                      4.858634
# 2016-01-15 04:00:00                      4.939416
#
#                      final.output.concentrate_au  final.output.recovery  \
# date
# 2016-01-15 00:00:00                    42.192020              70.541216
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 14149 entries, 2016-01-15 00:00:00 to 2018-08-18 10:59:59
# Data columns (total 86 columns):
# final.output.concentrate_ag                           14148 non-null float64
# final.output.concentrate_pb                           14148 non-null float64
# final.output.concentrate_sol                          13938 non-null float64
# final.output.concentrate_au                           14149 non-null float64
# final.output.recovery                                 14149 non-null float64
# final.output.tail_ag                                  14149 non-null float64
# final.output.tail_pb                                  14049 non-null float64
# final.output.tail_sol                                 14144 non-null float64
# final.output.tail_au                                  14149 non-null float64
# primary_cleaner.input.sulfate                         14129 non-null float64
# ...

# %% [markdown]
# Посмотрим на пропуски. Выведем топ-10 колонок в порядке убывания по доле пропущенных значений.

# %%
train.isna().mean().sort_values(ascending=False).head(10)
# Out:
# secondary_cleaner.output.tail_sol           0.113436
# rougher.state.floatbank10_e_air             0.030815
# rougher.input.floatbank11_xanthate          0.030249
# primary_cleaner.output.concentrate_sol      0.020213
# secondary_cleaner.state.floatbank2_a_air    0.015337
# final.output.concentrate_sol                0.014913
# rougher.input.feed_size                     0.010177
# final.output.tail_pb                        0.007068
# primary_cleaner.input.xanthate              0.007068
# rougher.input.feed_pb                       0.007068
# dtype: float64

# %% [markdown]
# Больше всего (около 11%) пропусков в признаке secondary_cleaner.output.tail_sol. На признаки rougher.state.floatbank10_e_air, rougher.input.floatbank11_xanthate, primary_cleaner.output.concentrate_sol, secondary_cleaner.state.floatbank2_a_air, final.output.concentrate_sol, rougher.input.feed_size приходится еще около 12% пропусков. Таким образом около 23% из 29% пропусков приходится на топ-7 признаков.
# Посмотрим какая доля выборки останется после удаления всех пропусков.

# %%
len(train.dropna())/len(train)
# Out:
# 0.7786416001130821

# %% [markdown]
# Не будем трогать признаки где пропусков менее 1%. Для топ-7 признаков в которых чаще всего встречаются пропуски построим гистограммы.

# %%
for i in list(train.isna().mean().sort_values(ascending=False).head(7).index):
    train.plot(kind='hist', y=i, bins=100, legend=True, grid=True, figsize = (10, 5))
    plt.show()

# %% [markdown]
# Характер распределения признаков с большим числом пропусков неододнороден, встречаются выборосы и распределение далекое от нормального. Удаление всех пропусков приведет к потери 22% данных. Учитывая объем возможных потерь данных и что выборка построена на наблюдениях с интервалом по времени 1 час, в дальнейшем заполним пропуски в признаках корреляцией.

# %% [markdown]
# #### Изучим тестовый датасет

# %%
test.head()
# Out:
#                      primary_cleaner.input.sulfate  \
# date
# 2016-09-01 00:59:59                     210.800909
# 2016-09-01 01:59:59                     215.392455
# 2016-09-01 02:59:59                     215.259946
# 2016-09-01 03:59:59                     215.336236
# 2016-09-01 04:59:59                     199.099327
#
#                      primary_cleaner.input.depressant  \
# date
# 2016-09-01 00:59:59                         14.993118
# 2016-09-01 01:59:59                         14.987471
# 2016-09-01 02:59:59                         12.884934
# 2016-09-01 03:59:59                         12.006805
# 2016-09-01 04:59:59                         10.682530
#
#                      primary_cleaner.input.feed_size  \
# date
# 2016-09-01 00:59:59                         8.080000
# 2016-09-01 01:59:59                         8.080000
# 2016-09-01 02:59:59                         7.786667
# 2016-09-01 03:59:59                         7.640000
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5856 entries, 2016-09-01 00:59:59 to 2017-12-31 23:59:59
# Data columns (total 52 columns):
# primary_cleaner.input.sulfate                 5554 non-null float64
# primary_cleaner.input.depressant              5572 non-null float64
# primary_cleaner.input.feed_size               5856 non-null float64
# primary_cleaner.input.xanthate                5690 non-null float64
# primary_cleaner.state.floatbank8_a_air        5840 non-null float64
# primary_cleaner.state.floatbank8_a_level      5840 non-null float64
# primary_cleaner.state.floatbank8_b_air        5840 non-null float64
# primary_cleaner.state.floatbank8_b_level      5840 non-null float64
# primary_cleaner.state.floatbank8_c_air        5840 non-null float64
# primary_cleaner.state.floatbank8_c_level      5840 non-null float64
# primary_cleaner.state.floatbank8_d_air        5840 non-null float64
# primary_cleaner.state.floatbank8_d_level      5840 non-null float64
# ...

# %% [markdown]
# Посмотрим на пропуски. Выведем топ-10 колонок в порядке убывания по доле пропущенных значений.

# %%
test.isna().mean().sort_values(ascending=False).head(10)
# Out:
# rougher.input.floatbank11_xanthate          0.060280
# primary_cleaner.input.sulfate               0.051571
# primary_cleaner.input.depressant            0.048497
# rougher.input.floatbank10_sulfate           0.043887
# primary_cleaner.input.xanthate              0.028347
# rougher.input.floatbank10_xanthate          0.021004
# rougher.input.feed_sol                      0.011441
# rougher.input.floatbank11_sulfate           0.009392
# rougher.input.feed_rate                     0.006831
# secondary_cleaner.state.floatbank3_a_air    0.005806
# dtype: float64

# %% [markdown]
# Больше всего пропусков в признаках rougher.input.floatbank11_xanthate, primary_cleaner.input.sulfate, primary_cleaner.input.depressant, rougher.input.floatbank10_sulfate. В них в сумме около 20% пропусков из 40%. Имеется 7 признаков с пропусками более 1%. В сумме в них 26.5% пропусков. В оставшихся 45 признаках имеется около 13.5% пропусков.
# Посмотрим какая доля выборки останется после удаления всех пропусков.

# %%
len(test.dropna())/len(test)
# Out:
# 0.9192281420765027

# %% [markdown]
# Не будем трогать признаки где пропусков менее 1%. Для топ-7 признаков в которых чаще всего встречаются пропуски построим гистограммы.

# %%
for i in list(test.isna().mean().sort_values(ascending=False).head(7).index):
    test.plot(kind='hist', y=i, bins=100, legend=True, grid=True, figsize = (10, 5))
    plt.show()

# %% [markdown]
# Характер распределения признаков с большим числом пропусков неододнороден, встречаются выборосы и распределение далекое от нормального. Удаление всех пропусков приведет к потери 8% данных. Выборка тестовая, поэтому удаление даже 8% данных считаю  крайне нежелательным. Так как выборка построена на наблюдениях с интервалом по времени 1 час, в дальнейшем заполним пропуски в признаках корреляцией.

# %% [markdown]
# #### Изучим полный датасет

# %%
full.head()
# Out:
#                      final.output.concentrate_ag  final.output.concentrate_pb  \
# date
# 2016-01-15 00:00:00                     6.055403                     9.889648
# 2016-01-15 01:00:00                     6.029369                     9.968944
# 2016-01-15 02:00:00                     6.055926                    10.213995
# 2016-01-15 03:00:00                     6.047977                     9.977019
# 2016-01-15 04:00:00                     6.148599                    10.142511
#
#                      final.output.concentrate_sol  \
# date
# 2016-01-15 00:00:00                      5.507324
# 2016-01-15 01:00:00                      5.257781
# 2016-01-15 02:00:00                      5.383759
# 2016-01-15 03:00:00                      4.858634
# 2016-01-15 04:00:00                      4.939416
#
#                      final.output.concentrate_au  final.output.recovery  \
# date
# 2016-01-15 00:00:00                    42.192020              70.541216
# ...

# %%
full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 19439 entries, 2016-01-15 00:00:00 to 2018-08-18 10:59:59
# Data columns (total 86 columns):
# final.output.concentrate_ag                           19438 non-null float64
# final.output.concentrate_pb                           19438 non-null float64
# final.output.concentrate_sol                          19228 non-null float64
# final.output.concentrate_au                           19439 non-null float64
# final.output.recovery                                 19439 non-null float64
# final.output.tail_ag                                  19438 non-null float64
# final.output.tail_pb                                  19338 non-null float64
# final.output.tail_sol                                 19433 non-null float64
# final.output.tail_au                                  19439 non-null float64
# primary_cleaner.input.sulfate                         19415 non-null float64
# ...

# %% [markdown]
# Посмотрим на пропуски. Выведем топ-10 колонок в порядке убывания по доле пропущенных значений.

# %%
full.isna().mean().sort_values(ascending=False).head(10)
# Out:
# secondary_cleaner.output.tail_sol           0.089922
# rougher.input.floatbank11_xanthate          0.023304
# rougher.state.floatbank10_e_air             0.022429
# primary_cleaner.output.concentrate_sol      0.019034
# secondary_cleaner.state.floatbank2_a_air    0.011317
# final.output.concentrate_sol                0.010854
# rougher.input.feed_size                     0.007459
# primary_cleaner.output.concentrate_pb       0.005967
# primary_cleaner.input.xanthate              0.005350
# final.output.tail_pb                        0.005196
# dtype: float64

# %% [markdown]
# Больше всего (около 9%) пропусков в признаке secondary_cleaner.output.tail_sol. На признаки с пропусками более 1% (всего их 6) приходится 17,7% из 23% пропусков. Посмотрим какая доля выборки останется после удаления всех пропусков.

# %%
len(full.dropna())/len(full)
# Out:
# 0.8279232470806112

# %% [markdown]
# Для признаков в которых пропусков больше 1% (топ-6 признаков по пропускам) построим гистограммы.

# %%
for i in list(full.isna().mean().sort_values(ascending=False).head(6).index):
    full.plot(kind='hist', y=i, bins=100, legend=True, grid=True, figsize = (10, 5))
    plt.show()

# %% [markdown]
# Характер распределения признаков с большим числом пропусков неододнороден, встречаются выборосы и распределение далекое от нормального. Удаление всех пропусков приведет к потери 17% данных. Выборка полная и нужна для проверки модели, поэтому заполнять пропуски не будем, оставим без изменений.

# %% [markdown]
# ### Проверим формулу вычисления эффективности обогащения

# %% [markdown]
# Проверим, что эффективность обогащения рассчитана правильно. Вычислите её на обучающей выборке для признака rougher.output.recovery. Найдём MAE между нашими расчётами и значением признака. Опишите выводы.

# %% [markdown]
# Напишем функцию расчета эффективности обогащения. Эффективность обогащения выражается в процентах, а в обучающей выборке имеются пропуски, плэтому зададим.

# %%
def recovery(C, F, T):
    numerator = (C*(F-T))
    denominator = (F*(C-T))
    rec = numerator / denominator * 100
    return rec

# %% [markdown]
# Применим функцию для расчета эффективности обогащения для признака rougher.output.recovery подставив в нее следуюшие значения:
# - C — доля золота в концентрате после флотации/очистки, колонка rougher.output.concentrate_au;
# - F — доля золота в сырье/концентрате до флотации/очистки, колонка rougher.input.feed_au;
# - T — доля золота в отвальных хвостах после флотации/очистки, колонка rougher.output.tail_au.

# %%
c, f, t = train['rougher.output.concentrate_au'], train['rougher.input.feed_au'], train['rougher.output.tail_au']
df = recovery(c, f, t)

# %% [markdown]
# Посчитаем среднее абсолютное отклонение заданных и расчетных значений (MAE) эффективности обогащения.

# %%
mae = mean_absolute_error(train[['rougher.output.recovery']], df)
mae
# Out:
# 9.682896147825551e-15

# %% [markdown]
# MAE крайне мало и равно 9.68 *10^(-15) поэтому можно считать формулу вычисления эффективности обогащения корректной.

# %% [markdown]
# ### Проанализируем признаки, недоступные в тестовой выборке.

# %% [markdown]
# Выведем размерность признаков выборок.

# %%
train.shape, test.shape, full.shape
# Out:
# ((14149, 86), (5856, 52), (19439, 86))

# %%
train.shape[1] - test.shape[1]
# Out:
# 34

# %% [markdown]
# В тестовой выборке нет 34 признаков.
# Выведем признаки, которые отсутствуют в тестовой выборке.

# %%
difference=list(set(train.columns)-set(test.columns))
difference
# Out:
# ['final.output.concentrate_au',
#  'rougher.output.concentrate_pb',
#  'final.output.tail_sol',
#  'final.output.concentrate_pb',
#  'final.output.recovery',
#  'rougher.output.tail_ag',
#  'rougher.output.tail_sol',
#  'rougher.calculation.floatbank11_sulfate_to_au_feed',
#  'primary_cleaner.output.concentrate_pb',
#  'rougher.calculation.sulfate_to_au_concentrate',
#  'secondary_cleaner.output.tail_pb',
#  'rougher.output.concentrate_sol',
#  'primary_cleaner.output.tail_ag',
#  'primary_cleaner.output.tail_au',
#  'secondary_cleaner.output.tail_au',
#  'rougher.calculation.floatbank10_sulfate_to_au_feed',
#  'rougher.output.concentrate_ag',
#  'final.output.tail_au',
#  'final.output.concentrate_sol',
#  'primary_cleaner.output.tail_sol',
#  'final.output.tail_ag',
#  'rougher.output.concentrate_au',
#  'secondary_cleaner.output.tail_sol',
#  'primary_cleaner.output.concentrate_ag',
#  'final.output.concentrate_ag',
#  'rougher.output.tail_pb',
#  'rougher.output.recovery',
# ...

# %% [markdown]
# В тестовых данных отсутствуют признаки:
# - параметры продукта (output) этапа rougher;
# - расчетные характеристики (calculation) этапа rougher;
# - параметры продукта (output) этапа primary_cleaner;
# - параметры продукта (output) этапа secondary_cleaner;
# - параметры продукта (output) этапа final - все признаки этого этапа.

# %% [markdown]
# В тестовых данных присутствуют признаки:
# - параметры сырья (input) этапа rougher;
# - параметры, характеризующие текущее состояние (state) этапа rougher;
# - параметры сырья (input) этапа primary_cleaner;
# - параметры, характеризующие текущее состояние (state) этапа primary_cleaner;
# - параметры, характеризующие текущее состояние (state) этапа secondary_cleaner.

# %% [markdown]
# В дальнейшем в качестве признаков для машинного обуения будем использовать только колонки имеющиеся в тестовой выборке.
# Присвоим переменные колонок признаков и целевых признаков для дальнейшего использования.

# %%
X_columns = test.columns
y_columns = ['rougher.output.recovery', 'final.output.recovery']

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# #### Обработка дубликатов

# %% [markdown]
# Проверим все данные на дубликаты.

# %%
train.duplicated().sum(), test.duplicated().sum(), full.duplicated().sum()
# Out:
# (0, 6, 0)

# %% [markdown]
# Удалим дубликаты, которые имеются только в тестовой выборке.

# %%
test = test.drop_duplicates()

# %% [markdown]
# #### Обработка пропусков

# %% [markdown]
# Выведем количество строк в обучающей, тренировочной, полной выборка. Также выведем разность суммы обучайщей и тренировочной выборок, и полной выборки, соответственно.

# %%
len(train), len(test), len(full), len(train) + len(test) - len(full)
# Out:
# (14149, 5850, 19439, 560)

# %% [markdown]
# Наблюдаем, что в полной выборке на 560 строк меньше, чем в сумме обучающей и тренировочной.
# Выведем количество пропусков в каждой выборке, соответственно

# %%
train.isna().sum().sum(), test.isna().sum().sum(), full.isna().sum().sum(), train.isna().sum().sum() + test.isna().sum().sum() - full.isna().sum().sum()
# Out:
# (4100, 2054, 4481, 1673)

# %% [markdown]
# Полная выборка меньше на 560 строк, но при этом число пропусков непропорционально меньше сумме пропусков в обучающей и тестовой выборке. Предположим, что в полной выборке могут быть значения которые пропущены в обучающей и тестовой выборках.
#
# Попробуем заполнить пропуски в train и test выборках с помощью выборки full. Выведем количество пропусков в обучающей и тестовой выборке, соответтветсвенно, после этой операции.

# %%
train.fillna(full).isna().sum().sum(), test.fillna(full).isna().sum().sum()
# Out:
# (4100, 2054)

# %% [markdown]
# Число пропусков не изменилось. Предположение не оправдалось.
#
# Проверим пропуски в целевых признаках обучающей выборки.

# %%
train[y_columns].isna().sum()
# Out:
# rougher.output.recovery    0
# final.output.recovery      0
# dtype: int64

# %% [markdown]
# Чтобы получить целевые признаки тестовой выборки, добавим к тестовой выборке недостающие данные из полной выборки.

# %%
test = test.join(full[difference])

# %% [markdown]
# Проверим пропуски в целевых признаках и размер тестовой выборки.

# %%
test[y_columns].isna().sum(), test.shape
# Out:
# (rougher.output.recovery    560
#  final.output.recovery      560
#  dtype: int64,
#  (5850, 86))

# %% [markdown]
# Те самые 560 строк разницы full и  train + test выборками. Достоверно заполнить не получится. Удаляем и проверяем размер выборки.

# %%
test = test.dropna(subset=y_columns)
test[y_columns].isna().sum(), test.shape
# Out:
# (rougher.output.recovery    0
#  final.output.recovery      0
#  dtype: int64,
#  (5290, 86))

# %% [markdown]
# Теперь, когда пропуски в целевых признаках обучающей и тестовой выборки отсутствуют, заполним пропуски в выборках интерполяцией.

# %%
train = train.interpolate(method='time')
test = test.interpolate(method='time')

# %% [markdown]
# ### Выводы
# - Исходя из анализа датасетов принят способ заполнения пропусков в признаках методом интерполяции.
# - Формула для расчета эффективности обогащения проверена и исходя из метрики MAE равной 9.68 *10^(-15) принята корректной.
# - Определены признаки отсутствующие в тестовой выборке. При машинном обучении из обучающей выборки будут исключены эти признаки.
# - Пропуски в целевых признаках тестовой выборке удалены.
# - Пропуски в признаках обих выборок заполнены интерпояцией.
# - Обучающая выборка имеет 14149 объектов, тестовая - 5290.

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# ### Как меняется концентрация металлов (Au, Ag, Pb) на различных этапах очистки.

# %% [markdown]
# Для обучающей выборки построим распределение изменения концентрации Au, Ag, Pb в продукте на этапах:
# - поступления смеси золотой руды (rougher.input.feed),
# - после флотации (rougher.output.concentrate),
# - после первичной очистки (primary_cleaner.output.concentrate),
# - в финальном концентрате ('final.output.concentrate').
#
# Распределение конентрации металлов в отвальных хвостах на этапах:
# - после флотации (rougher.output.tail),
# - после первичной очистки (primary_cleaner.output.tail),
# - после Вторичной очистки (secondary_cleaner.output.tail),
# - в финальном концентрате (final.output.tail).

# %%
process = ['rougher.input.feed',
           'rougher.output.concentrate',
           'primary_cleaner.output.concentrate',           
           'final.output.concentrate']

process_tail = ['rougher.output.tail',
                'primary_cleaner.output.tail',
                'secondary_cleaner.output.tail',
                'final.output.tail']

metals = ['au', 'ag', 'pb']

fig, axs = plt.subplots(4, 1, figsize=(12, 20), constrained_layout=True)
fig.suptitle('Metal concentrations in product by stage', fontsize=24)

for stage, ax in zip(process, axs):
    ax.set_title(stage)
    for metal in metals:        
        cols = train.columns.str.contains(stage+'_'+metal)
        sns_ax = sns.distplot(train.loc[:, cols], label=metal, hist=False, ax=ax)    
        sns_ax.set(xlim=(-5, 55))
plt.legend()

fig, axs = plt.subplots(4, 1, figsize=(12, 20), constrained_layout=True)
fig.suptitle('Metal concentrations in tail by stage', fontsize=24)

for stage, ax in zip(process_tail, axs):
    ax.set_title(stage)
    for metal in metals:        
        cols = train.columns.str.contains(stage+'_'+metal)
        sns_ax = sns.distplot(train.loc[:, cols], label=metal, hist=False, ax=ax)  
        sns_ax.set(xlim=(-5, 35))
plt.legend()

plt.show()

# %% [markdown]
# - В концентрате:
# В процессе флотации/очистки увеличивается уменьшается разброс значений концентрация золота.
# Концентрация серебра после флотации увеличивется, но на следующих этапах уменьшается.
# Концентрация свинца несущественно увеличивается после флотации/очистки.
#
#
# - В отвальных хвостах:
# Концентрация золота до финального концентрата растет. В финальном концентрате снижается, так же снижается разброс значений.
# Динамика концентрация серебра соответствует динамике золота, но на всех этапах концентрация серебра выше золота.
# Характер изменения концентрации свинца так же в соответствует динамике золота.

# %% [markdown]
# Строим аналогичные графики распределения для тестовой выборки.

# %%
fig, axs = plt.subplots(4, 1, figsize=(12, 20), constrained_layout=True)
fig.suptitle('Metal concentrations in product by stage', fontsize=24)

for stage, ax in zip(process, axs):
    ax.set_title(stage)
    for metal in metals:        
        cols = test.columns.str.contains(stage+'_'+metal)
        sns_ax = sns.distplot(test.loc[:, cols], label=metal, hist=False, ax=ax)    
        sns_ax.set(xlim=(-5, 55))
plt.legend()

fig, axs = plt.subplots(4, 1, figsize=(12, 20), constrained_layout=True)
fig.suptitle('Metal concentrations in tail by stage', fontsize=24)

for stage, ax in zip(process_tail, axs):
    ax.set_title(stage)
    for metal in metals:        
        cols = test.columns.str.contains(stage+'_'+metal)
        sns_ax = sns.distplot(test.loc[:, cols], label=metal, hist=False, ax=ax)  
        sns_ax.set(xlim=(-5, 35))
plt.legend()

plt.show()

# %% [markdown]
# - В концентрате:
# Динамика концентрации металлов на всех этапах тесовой выборки соответствует обучающей.
#
#
# - В отвальных хвостах:
# Динамика концентрации металлов на всех этапах тесовой выборки соответствует обучающей.

# %% [markdown]
# ### Сравние распределения размеров гранул сырья на обучающей и тестовой выборках.

# %% [markdown]
# Построим графики распределения и ящики с усами для размеров гранул сырья обучающей и тестовой выборки.

# %%
plt.figure(figsize=(16,8))
sns.distplot(train['rougher.input.feed_size'], label='train_rougher')
sns.distplot(test['rougher.input.feed_size'], label='test_rougher')
plt.legend()
plt.show()

# %% [markdown]
# Построим боксплоты.

# %%
for df in [train, test]:
    df.boxplot(column='rougher.input.feed_size')
    plt.ylim(20, 95)
    plt.show()

# %% [markdown]
# Распределение в обучающей и тестовой выборке схожее, близко к нормальному, но имеются хвосты. Отфильруем в обучающей  выборке значения размеров гранул сырья примерно по усам боксплота (значения 20, 95).

# %%
train = train[(train['rougher.input.feed_size'] > 20) & (train['rougher.input.feed_size'] < 95)]

# %% [markdown]
# Построим аналогичные графики распределения размеров гранул после флотации.

# %%
plt.figure(figsize=(16,8))
sns.distplot(train['primary_cleaner.input.feed_size'], label='train_primary_cleaner')
sns.distplot(test['primary_cleaner.input.feed_size'], label='test_primary_cleaner')
plt.legend()
plt.show()

# %%
for df in [train, test]:
    df.boxplot(column='primary_cleaner.input.feed_size')
    plt.ylim(5.5, 9)
    plt.show()

# %% [markdown]
# Так же отфильтруем значения в признаке primary_cleaner.input.feed_size примерно по усам боксплота (значения 5,5 и 9).

# %%
train = train[(train['primary_cleaner.input.feed_size'] > 5.5) & (train['primary_cleaner.input.feed_size'] < 9)]

# %% [markdown]
# ### Исследуйте суммарную концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах.

# %% [markdown]
# Построим распределение суммарной концентрации всех веществ на разных стадиях для обучающей выборки.

# %%
plt.figure(figsize=(16,8))
plt.title('Summary concentrations of all substances by stage in train data', fontsize=24)

for stage in list(process):
    ax.set_title(stage)
    sum_train = train[stage+ '_ag'] + train[stage+ '_au'] + train[stage+ '_pb'] + train[stage+ '_sol']
    sns_ax = sns.distplot(sum_train, label=process, bins=100)
plt.legend(process, fontsize=12)
plt.xticks(np.arange(0, 102, 2))
plt.xlabel('Summary concentrations', fontsize=15)
plt.show()

# %% [markdown]
# Наблюдаем большое число нулевых значений суммарной концентрации всех веществ. Выглядит аномально. В дальнейшем удалим значения меньше 1 из выборки.

# %% [markdown]
# Аналогичное распределение для тестовой выборки

# %%
plt.figure(figsize=(16,8))
plt.title('Summary concentrations of all substances by stage in test data', fontsize=24)

for stage in list(process):
    ax.set_title(stage)
    sum_test = test[stage+ '_ag'] + test[stage+ '_au'] + test[stage+ '_pb'] + test[stage+ '_sol']
    sns_ax = sns.distplot(sum_test, label=process, bins=100)
plt.legend(process, fontsize=12)
plt.xticks(np.arange(0, 102, 2))
plt.xlabel('Summary concentrations', fontsize=15)
plt.show()

# %% [markdown]
# Так же в дальнейшем удалим значения меньше 1 из выборки.

# %% [markdown]
# Добавляем колонки с расчетными суммарными концентрациями всех веществ в обучающий датафрейм.

# %%
for stage in process:
    sum_train[stage] = train[stage+ '_ag'] + train[stage+ '_au'] + train[stage+ '_pb'] + train[stage+ '_sol']
    df_sum_train=sum_train[str(stage)].to_frame(name=str(stage))
    train = train.join(df_sum_train)

# %%
train[process].head(5)
# Out:
#                      rougher.input.feed  rougher.output.concentrate  \
# date
# 2016-01-15 00:00:00           51.680034                   66.424950
# 2016-01-15 01:00:00           50.659114                   67.012710
# 2016-01-15 02:00:00           50.609929                   66.103793
# 2016-01-15 03:00:00           51.061546                   65.752751
# 2016-01-15 04:00:00           47.859163                   65.908382
#
#                      primary_cleaner.output.concentrate  \
# date
# 2016-01-15 00:00:00                           72.640924
# 2016-01-15 01:00:00                           72.543485
# 2016-01-15 02:00:00                           72.095042
# 2016-01-15 03:00:00                           59.957723
# 2016-01-15 04:00:00                           71.321010
#
#                      final.output.concentrate
# date
# 2016-01-15 00:00:00                 63.644396
# 2016-01-15 01:00:00                 63.957723
# 2016-01-15 02:00:00                 64.311180
# ...

# %% [markdown]
# Удаляем из обучающей выборки объекты с суммарной конценрацией веществ меньше 1.Выводим долю оставшихся строк.

# %%
train_drop = train[(
    train['rougher.input.feed'] > 1) & (
    train['rougher.output.concentrate'] > 1) & (
    train['final.output.concentrate'] > 1) & (
    train['primary_cleaner.output.concentrate'] > 1)]

train_drop.shape[0] / train.shape[0]
# Out:
# 0.9612283787745529

# %% [markdown]
# Аналогичные операции совершаем для тестовой выборки.

# %%
for stage in process:
    sum_test[stage] = test[stage+ '_ag'] + test[stage+ '_au'] + test[stage+ '_pb'] + test[stage+ '_sol']
    df_sum_test=sum_test[str(stage)].to_frame(name=str(stage))
    test = test.join(df_sum_test)

# %%
test_drop = test[(
    test['rougher.input.feed'] > 1) & (
    test['rougher.output.concentrate'] > 1) & (
    test['final.output.concentrate'] > 1) & (
    test['primary_cleaner.output.concentrate'] > 1)]

test_drop.shape[0] / test.shape[0]
# Out:
# 0.9684310018903591

# %% [markdown]
# ### Выводы
# При рассмотрении динамики концентрации металлов на каждом этапе можно сказать следующее.
#
# В концентрате:
# - В процессе флотации/очистки увеличивается уменьшается разброс значений концентрация золота.
# - Концентрация серебра после флотации увеличивется, но на следующих этапах уменьшается.
# - Концентрация свинца несущественно увеличивается после флотации/очистки.
#
# В отвальных хвостах:
# - Концентрация золота до финального концентрата растет. В финальном концентрате снижается, так же снижается разьрос значений.
# - Динамика концентрация серебра соответствует динамике золота, но на всех этапах концентрация серебра выше золота.
# - Характер изменения концентрации свинца так же в соответствует динамике золота.
#
# Распределение размеров гранул сырья и продукта в обучающей и тестовой выборке схожее, близко к нормальному.
#
# При анализе суммароной концентрации всех веществ обнаружено большое число околонулевых значений, которые являются аномалией. После удаления значений меньше 1 из обучающей и тестовой выборки сохранилось более 96% данных.

# %% [markdown]
# ## Модель

# %% [markdown]
# ### Функция для вычисления итоговой sMAPE.

# %%
def sMAPE(y_true, predict):
    rougher, final = ((abs(y_true - predict) / ((abs(y_true) + abs(predict)) / 2)).mean() * 100)    
    result = (0.25 * rougher + 0.75 * final)
    return result

# %% [markdown]
# Делаем функцию sMAPE метрикой для оценки модели.

# %%
smape = make_scorer(sMAPE, greater_is_better=False)

# %% [markdown]
# ### Определяем признаки и целевые признаки.

# %% [markdown]
# Выделим из выборок признаки по списку признаков и целевых признаков определенных при изучении датасетов.

# %%
X_train = train_drop[X_columns]
y_train = train_drop[y_columns]
X_test = test_drop[X_columns]
y_test = test_drop[y_columns]

# %% [markdown]
# Выведем размерности признаков и целевых признаков обучающей выборки.

# %%
X_train.shape, y_train.shape
# Out:
# ((13115, 52), (13115, 2))

# %% [markdown]
# Аналогично для тестовой выборки.

# %%
X_test.shape, y_test.shape
# Out:
# ((5123, 52), (5123, 2))

# %% [markdown]
# Масштабируем признаки.

# %%
scaler = StandardScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ### Линейная регрессия

# %% [markdown]
# Задаем Pipeline и параметры для GridSearchCV.

# %%
steps_lr = [('scaler', StandardScaler()), ('lr', LinearRegression())]
pipe_lr = Pipeline(steps_lr)

params_lr = {
    'lr__fit_intercept' : [True, False],
    'lr__normalize': [True, False],
    'lr__n_jobs' :[None, -1]}

# %% [markdown]
# Кросс-валидацией по 4-м фолдам ищем оптимальные параметры линейной регрессии с мультивыходными признаками. В качесве метрики используем функцию sMAPE.

# %%
search_lr = GridSearchCV(estimator=pipe_lr, param_grid=params_lr, scoring=smape, cv = 3)
result_lr = search_lr.fit(X_train, y_train)
y_pred_lr = result_lr.best_estimator_.predict(X_test)
print('Best Score: %s' % abs(result_lr.best_score_))
print('Best Hyperparameters: %s' % result_lr.best_params_)
# Out:
# Best Score: 9.54324013299503
# Best Hyperparameters: {'lr__fit_intercept': True, 'lr__n_jobs': None, 'lr__normalize': True}

# %% [markdown]
# ### Дерево решений

# %% [markdown]
# Задаем Pipeline и параметры для GridSearchCV.

# %%
steps_dt = [('scaler', StandardScaler()), ('dt', DecisionTreeRegressor())]
pipe_dt = Pipeline(steps_dt)

params_dt = {
    'dt__max_depth' : [*range(1, 12, 2)],
    'dt__min_samples_leaf': [*range(1, 4, 1)],
    'dt__min_samples_split' :[*range(2, 7, 2)]}

# %% [markdown]
# Кросс-валидацией по 4-м фолдам ищем оптимальные параметры дерева решений с мультивыходными признаками. В качесве метрики используем функцию sMAPE.

# %%
search_dt = GridSearchCV(estimator=pipe_dt, param_grid=params_dt, scoring=smape, cv = 4)
result_dt = search_dt.fit(X_train, y_train)
y_pred_dt = result_dt.best_estimator_.predict(X_test)
print('Best Score: %s' % abs(result_dt.best_score_))
print('Best Hyperparameters: %s' % result_dt.best_params_)
# Out:
# Best Score: 9.46159677913504
# Best Hyperparameters: {'dt__max_depth': 3, 'dt__min_samples_leaf': 1, 'dt__min_samples_split': 2}

# %% [markdown]
# ### Тестируем модели

# %%
model=result_lr.best_estimator_ 

model.fit(X_train_scaled, y_train)
y_pred = model.predict(X_test_scaled)
sMAPE(y_test, y_pred)
# Out:
# 7.443702578714085

# %%
model=result_dt.best_estimator_ 

model.fit(X_train_scaled, y_train)
y_pred = model.predict(X_test_scaled)
sMAPE(y_test, y_pred)
# Out:
# 9.45478156735565

# %% [markdown]
# ## Выводы

# %% [markdown]
# 1) При изучении датасета:
# - Произведено заполнение пропусков в признаках методом интерполяции.
# - Формула для расчета эффективности обогащения проверена и исходя из метрики MAE равной 9.68 *10^(-15) принята корректной.
# - Определены признаки отсутствующие в тестовой выборке. Машинное обучение произведено на признаках доступных в тестовой выборке.
# - Пропуски в целевых признаках тестовой выборке удалены.
#
# 2) При анализе данных:
#
# При рассмотрении динамики концентрации металлов на каждом этапе можно сказать следующее.
#
# В концентрате:
# - В процессе флотации/очистки увеличивается уменьшается разброс значений концентрация золота.
# - Концентрация серебра после флотации увеличивется, но на следующих этапах уменьшается.
# - Концентрация свинца несущественно увеличивается после флотации/очистки.
#
# В отвальных хвостах:
# - Концентрация золота до финального концентрата растет. В финальном концентрате снижается, так же снижается разьрос значений.
# - Динамика концентрация серебра соответствует динамике золота, но на всех этапах концентрация серебра выше золота.
# - Характер изменения концентрации свинца так же в соответствует динамике золота.
#
# Распределение размеров гранул сырья и продукта в обучающей и тестовой выборке схожее, близко к нормальному.
#
# При анализе суммароной концентрации всех веществ обнаружено большое число нулевых значений, которые являются аномалией. После удаления значений меньше 1 из обучающей и тестовой выборки сохранилось более 96% данных.
#
# - Всего в обучающей выборке 52/2 признаков/целевых признаков в 13115 объектах.
# - В тренировочной выборке содержит 52/2 в 5123 объектах.
#
# 3) Обучение моделей:
# - В качестве метрики использовалась кастомная фукнция sMAPE
# - Для мультивыходной регрессии (Multioutput Regression) с кросвалидацией по 4 фолдам произведен подбор гиперпараметров моделей линейной регрессии и дерева решений.
# - При кроссвалидации лучший результат показала модель дерева решений с sMAPE равный 9,46%, у линейной регрессии sMAPE составил 9,54%.
# - При тестировании моделей для дерева решений и линейной регрессии sMAPE составил соответственно 9,45% и 7,44%.
